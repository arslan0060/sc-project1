# %%
# %pylab inline
z  = loadtxt('z.txt')
P4=loadtxt('p4.txt');
P8=loadtxt('p8.txt');
P12=loadtxt('p12.txt')
cos=loadtxt('f.txt')
plot(z, P4, 'b-',  label='$P_4(x)$')
plot(z, P8, 'r-', label='$P_8(x)$')
plot(z, P12, 'k-',  label='${P_1}_2(x)$')
plot(z, cos, 'pink', linestyle='dashed',label='$Cos(x)$')
xlabel('x')
ylabel('y')
title('Taylor Polynomials and cos(x)')
legend()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['cos']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
err4=loadtxt('err4.txt');
err8=loadtxt('err8.txt');
err12=loadtxt('err12.txt')
semilogy(z, err4, 'k-',  label='$Error P_4(x)$')
semilogy(z, err8, 'g-', label='$Error P_8(x)$')
semilogy(z, err12, 'b-',  label='$Error {P_1}_2(x)$')
legend()
xlabel('x')
ylabel('y')
title('Taylor Polynomial Error')
legend()
